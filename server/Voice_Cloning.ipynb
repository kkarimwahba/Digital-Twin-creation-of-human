# %%
# Changing the current directory to the repository's directory
# %cd Real-Time-Voice-Cloning/
# Out:
# c:\Users\marti\Downloads\Real-Time-Voice-Cloning

# %%
# # Installing the dependencies
# !pip install -q -r requirements.txt
# !apt-get install -qq libportaudio2

# %%
# import gdown

# # Google Drive file ID
# file_id = '1n1sPXvT34yXFLT47QZA6FIRGrwMeSsZc'

# # Output file name
# output_file = 'pretrained.zip'

# # Download the file from Google Drive
# gdown.download(f'https://drive.google.com/uc?id={file_id}', output_file, quiet=False)

# %%
# import zipfile
# import os

# # Path to the downloaded zip file
# zip_file_path = r'D:\Real-Time-Voice-Cloning\pretrained.zip'

# # Directory to extract the contents
# extract_dir = r'D:\Real-Time-Voice-Cloning\pretrained/'

# # Create the directory if it doesn't exist
# os.makedirs(extract_dir, exist_ok=True)

# # Extract the contents of the zip file
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)

# print(f"Successfully extracted contents to '{extract_dir}'")

# %%
# # Downloading pretrained data and unzipping it
# !gdown https://drive.google.com/uc?id=1n1sPXvT34yXFLT47QZA6FIRGrwMeSsZc
# !unzip pretrained.zip

# %%
# pip install synthesizer

# %%
# Initializing all the encoder libraries
from IPython.display import Audio
from IPython.utils import io
from synthesizer.inference import Synthesizer
from encoder import inference as encoder
from vocoder import inference as vocoder
from pathlib import Path
import numpy as np
import librosa
encoder_weights = Path(r"D:\Real-Time-Voice-Cloning\encoder\saved_models\pretrained.pt")
vocoder_weights = Path(r"D:\Real-Time-Voice-Cloning\vocoder\saved_models\pretrained\pretrained.pt")
syn_dir = Path(r"D:\Real-Time-Voice-Cloning\synthesizer\saved_models\logs-pretrained\taco_pretrained")
encoder.load_model(encoder_weights)
synthesizer = Synthesizer(syn_dir)
vocoder.load_model(vocoder_weights)
# Out:
# Loaded encoder "pretrained.pt" trained to step 1564501
# Found synthesizer "pretrained" trained to step 278000
# Building Wave-RNN
# Trainable Parameters: 4.481M
# Loading model weights at D:\Real-Time-Voice-Cloning\vocoder\saved_models\pretrained\pretrained.pt

# %%
text = "Subscribe to the channel"

# %%
in_fpath = Path(r"D:\Real-Time-Voice-Cloning\25.wav")
reprocessed_wav = encoder.preprocess_wav(in_fpath)
original_wav, sampling_rate = librosa.load(in_fpath)
preprocessed_wav = encoder.preprocess_wav(original_wav, sampling_rate)
embed = encoder.embed_utterance(preprocessed_wav)
with io.capture_output() as captured:
  specs = synthesizer.synthesize_spectrograms([text], [embed])
generated_wav = vocoder.infer_waveform(specs[0])
generated_wav = np.pad(generated_wav, (0, synthesizer.sample_rate), mode="constant")
display(Audio(generated_wav, rate=synthesizer.sample_rate))
# Out:
# {| ████████████████ 28500/28800 | Batch Size: 3 | Gen Rate: 1.5kHz | }
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Follow this YouTube channel for more such tutorials,
# Link : https://www.youtube.com/user/19daredevill
